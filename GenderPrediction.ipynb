# %%
from sklearn import tree
import pandas as pd

# %%
data = pd.read_csv("C:\Users\wacalvo\Desktop\Personas.csv", header=0)
# Out:
#   File "<ipython-input-5-eb9ec813f727>", line 1
#     data = pd.read_csv("C:\Users\wacalvo\Desktop\Personas.csv", header=0)
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
data = pd.read_csv('C:\Users\wacalvo\Desktop\Personas.csv', header=0)
# Out:
#   File "<ipython-input-6-cb8842504ab8>", line 1
#     data = pd.read_csv('C:\Users\wacalvo\Desktop\Personas.csv', header=0)
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
data = pd.read_csv(r'C:\Users\wacalvo\Desktop\Personas.csv', header=0)

# %%
data
# Out:
#    Sexo  Estatura  Peso Altura
# 0     h        35    75    1,7
# 1     m        57    88   1,59
# 2     h        40    81   1,66
# 3     h        46    73   1,66
# 4     m        67    97   1,68
# 5     m        68    99   1,58
# 6     m        65    85   1,56
# 7     h        60    70   1,65
# 8     h        56    94   1,72
# 9     m        66    68   1,51
# 10    h        54    87   1,73
# 11    h        52    87   1,82
# 12    m        65    82   1,58
# 13    m        55    79   1,55
# 14    m        67    91   1,61
# 15    h        45    96   1,78
# 16    h        44    92    1,8
# 17    m        38    65    1,6
# 18    h        34    75    1,7
# 19    h        39    84   1,67
# 20    m        44    81   1,66
# 21    m        44    73   1,66
# 22    m        43    97   1,68
# 23    h        48    95   1,58
# 24    h        50    89   1,56
# 25    m        44    71   1,65
# 26    h        57    94   1,72
# 27    m        59    68   1,51
# 28    h        44    91   1,73
# ...

# %%
datos["Sexo"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c5b69234e0be> in <module>()
# ----> 1 datos["Sexo"]
#
# NameError: name 'datos' is not defined

# %%
data["Sexo"]
# Out:
# 0     h
# 1     m
# 2     h
# 3     h
# 4     m
# 5     m
# 6     m
# 7     h
# 8     h
# 9     m
# 10    h
# 11    h
# 12    m
# 13    m
# 14    m
# 15    h
# 16    h
# 17    m
# 18    h
# 19    h
# 20    m
# 21    m
# 22    m
# 23    h
# 24    h
# 25    m
# 26    h
# 27    m
# 28    h
# 29    h
#      ..
# 70    m
# 71    h
# 72    h
# 73    m
# 74    m
# 75    m
# 76    h
# 77    h
# 78    m
# 79    h
# 80    h
# 81    m
# 82    m
# 83    m
# 84    h
# 85    h
# 86    m
# 87    h
# 88    h
# 89    m
# 90    m
# 91    m
# 92    h
# 93    h
# 94    m
# 95    h
# 96    m
# 97    h
# 98    h
# 99    m
# Name: Sexo, Length: 100, dtype: object

# %%
clear

# %%
for contador in data: 
    print("hola ")
# Out:
# hola
# hola
# hola
# hola

# %%
for contador in data: 
    print("hola ")
# Out:
# hola
# hola
# hola
# hola

# %%
data
# Out:
#    Sexo  Estatura  Peso Altura
# 0     h        35    75    1,7
# 1     m        57    88   1,59
# 2     h        40    81   1,66
# 3     h        46    73   1,66
# 4     m        67    97   1,68
# 5     m        68    99   1,58
# 6     m        65    85   1,56
# 7     h        60    70   1,65
# 8     h        56    94   1,72
# 9     m        66    68   1,51
# 10    h        54    87   1,73
# 11    h        52    87   1,82
# 12    m        65    82   1,58
# 13    m        55    79   1,55
# 14    m        67    91   1,61
# 15    h        45    96   1,78
# 16    h        44    92    1,8
# 17    m        38    65    1,6
# 18    h        34    75    1,7
# 19    h        39    84   1,67
# 20    m        44    81   1,66
# 21    m        44    73   1,66
# 22    m        43    97   1,68
# 23    h        48    95   1,58
# 24    h        50    89   1,56
# 25    m        44    71   1,65
# 26    h        57    94   1,72
# 27    m        59    68   1,51
# 28    h        44    91   1,73
# ...

# %%
for contador in data: 
    print(contador)
# Out:
# Sexo
# Estatura
# Peso
# Altura

# %%
data
# Out:
#    Sexo  Estatura  Peso Altura
# 0     h        35    75    1,7
# 1     m        57    88   1,59
# 2     h        40    81   1,66
# 3     h        46    73   1,66
# 4     m        67    97   1,68
# 5     m        68    99   1,58
# 6     m        65    85   1,56
# 7     h        60    70   1,65
# 8     h        56    94   1,72
# 9     m        66    68   1,51
# 10    h        54    87   1,73
# 11    h        52    87   1,82
# 12    m        65    82   1,58
# 13    m        55    79   1,55
# 14    m        67    91   1,61
# 15    h        45    96   1,78
# 16    h        44    92    1,8
# 17    m        38    65    1,6
# 18    h        34    75    1,7
# 19    h        39    84   1,67
# 20    m        44    81   1,66
# 21    m        44    73   1,66
# 22    m        43    97   1,68
# 23    h        48    95   1,58
# 24    h        50    89   1,56
# 25    m        44    71   1,65
# 26    h        57    94   1,72
# 27    m        59    68   1,51
# 28    h        44    91   1,73
# ...

# %%
type for data
# Out:
#   File "<ipython-input-17-cd964cf1dff2>", line 1
#     type for data
#            ^
# SyntaxError: invalid syntax

# %%
type  data
# Out:
#   File "<ipython-input-18-3973d1d14063>", line 1
#     type  data
#              ^
# SyntaxError: invalid syntax

# %%
type data
# Out:
#   File "<ipython-input-19-535469f3b21b>", line 1
#     type data
#             ^
# SyntaxError: invalid syntax

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
AlturadatosX = data["Estatura","Peso","Altura"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Estatura', 'Peso', 'Altura')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
AlturadatosX = data[["Estatura","Peso","Altura"]
# Out:
#   File "<ipython-input-22-750f83a76a0f>", line 1
#     AlturadatosX = data[["Estatura","Peso","Altura"]
#                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
AlturadatosX = [data['Estatura'],data['Peso'],data['Altura']]

# %%
AlturadatosX
# Out:
# [0     35
#  1     57
#  2     40
#  3     46
#  4     67
#  5     68
#  6     65
#  7     60
#  8     56
#  9     66
#  10    54
#  11    52
#  12    65
#  13    55
#  14    67
#  15    45
#  16    44
#  17    38
#  18    34
#  19    39
#  20    44
#  21    44
#  22    43
#  23    48
#  24    50
#  25    44
#  26    57
#  27    59
#  28    44
#  29    36
#        ..
#  70    52
#  71    65
#  72    55
#  73    67
#  74    45
#  75    44
#  76    38
#  77    34
#  78    39
#  79    44
#  80    38
#  81    71
#  82    78
#  83    55
#  84    44
#  85    43
#  86    48
#  87    50
#  88    39
#  89    44
#  90    38
#  91    34
#  92    39
#  93    55
#  94    72
#  95    43
#  96    48
#  97    50
#  98    45
#  99    58
#  Name: Estatura, Length: 100, dtype: int64, 0     75
#  1     88
#  2     81
#  3     73
#  4     97
#  5     99
#  6     85
#  7     70
#  8     94
#  9     68
#  10    87
#  11    87
#  12    82
#  13    79
#  14    91
#  15    96
#  16    92
#  17    65
# ...

# %%
data
# Out:
#    Sexo  Estatura  Peso Altura
# 0     h        35    75    1,7
# 1     m        57    88   1,59
# 2     h        40    81   1,66
# 3     h        46    73   1,66
# 4     m        67    97   1,68
# 5     m        68    99   1,58
# 6     m        65    85   1,56
# 7     h        60    70   1,65
# 8     h        56    94   1,72
# 9     m        66    68   1,51
# 10    h        54    87   1,73
# 11    h        52    87   1,82
# 12    m        65    82   1,58
# 13    m        55    79   1,55
# 14    m        67    91   1,61
# 15    h        45    96   1,78
# 16    h        44    92    1,8
# 17    m        38    65    1,6
# 18    h        34    75    1,7
# 19    h        39    84   1,67
# 20    m        44    81   1,66
# 21    m        44    73   1,66
# 22    m        43    97   1,68
# 23    h        48    95   1,58
# 24    h        50    89   1,56
# 25    m        44    71   1,65
# 26    h        57    94   1,72
# 27    m        59    68   1,51
# 28    h        44    91   1,73
# ...

# %%
for element in data.rows
    print row['Sexo']
# Out:
#   File "<ipython-input-26-5868dc9bfe42>", line 1
#     for element in data.rows
#                             ^
# SyntaxError: invalid syntax

# %%
for element in data.rows
    print row['Sexo']
# Out:
#   File "<ipython-input-27-5868dc9bfe42>", line 1
#     for element in data.rows
#                             ^
# SyntaxError: invalid syntax

# %%
for element in data
    print row['Sexo']
# Out:
#   File "<ipython-input-28-f3ac5afb35d6>", line 1
#     for element in data
#                        ^
# SyntaxError: invalid syntax

# %%
for element in data.rows:
    print row['Sexo']
# Out:
#   File "<ipython-input-29-683169873c6c>", line 2
#     print row['Sexo']
#             ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(row['Sexo'])?

# %%
for element in data
    print(row['Sexo'])
# Out:
#   File "<ipython-input-30-dc1ef8b3eb7c>", line 1
#     for element in data
#                        ^
# SyntaxError: invalid syntax

# %%
for element in data:
    print(row['Sexo'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1fc60950f4c0> in <module>()
#       1 for element in data:
# ----> 2     print(row['Sexo'])
#
# NameError: name 'row' is not defined

# %%
for element in data.rows:
    print(element['Sexo'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-8820171d043b> in <module>()
# ----> 1 for element in data.rows:
#       2     print(element['Sexo'])
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
for element in data:
    print(element['Sexo'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-b0882aed2e80> in <module>()
#       1 for element in data:
# ----> 2     print(element['Sexo'])
#
# TypeError: string indices must be integers

# %%
for index, row in data.iterrows():
    print(row['c1'], row['c2'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3108             try:
# -> 3109                 return libindex.get_value_box(s, key)
#    3110             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-1f9f5c4fd72d> in <module>()
#       1 for index, row in data.iterrows():
# ----> 2     print(row['c1'], row['c2'])
#
# ...

# %%
for index, row in data.iterrows():
    print(row['Sexo'], row['Altura'])
# Out:
# h 1,7
# m 1,59
# h 1,66
# h 1,66
# m 1,68
# m 1,58
# m 1,56
# h 1,65
# h 1,72
# m 1,51
# h 1,73
# h 1,82
# m 1,58
# m 1,55
# m 1,61
# h 1,78
# h 1,8
# m 1,6
# h 1,7
# h 1,67
# m 1,66
# m 1,66
# m 1,68
# h 1,58
# h 1,56
# m 1,65
# h 1,72
# m 1,51
# h 1,73
# h 1,82
# m 1,58
# m 1,55
# m 1,61
# h 1,78
# h 1,8
# m 1,6
# h 1,7
# h 1,78
# m 1,66
# m 1,66
# m 1,68
# h 1,81
# h 1,74
# m 1,65
# h 1,72
# h 1,79
# m 1,73
# m 1,82
# m 1,58
# h 1,55
# h 1,61
# m 1,78
# h 1,8
# m 1,6
# h 1,7
# h 1,73
# m 1,63
# m 1,7
# m 1,59
# h 1,66
# h 1,66
# m 1,6
# h 1,58
# m 1,78
# m 1,62
# m 1,6
# h 1,7
# h 1,73
# m 1,7
# h 1,86
# m 1,66
# h 1,83
# h 1,8
# m 1,58
# m 1,56
# m 1,65
# h 1,72
# h 1,51
# m 1,65
# h 1,82
# h 1,58
# m 1,55
# m 1,61
# m 1,57
# h 1,56
# h 1,72
# m 1,51
# h 1,73
# h 1,82
# m 1,58
# m 1,55
# m 1,61
# h 1,78
# h 1,8
# m 1,6
# h 1,7
# m 1,73
# h 1,7
# h 1,6
# m 1,66

# %%
sexos = []
datosComparativos = []
for index, row in data.iterrows():
    sexos.append(row['Sexo'])

# %%
for index, row in data.iterrows():
    datosComparativos.append(row['Estatura'],row['Peso'],row['Altura'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-e78919eb1ea8> in <module>()
#       1 for index, row in data.iterrows():
# ----> 2     datosComparativos.append(row['Estatura'],row['Peso'],row['Altura'])
#
# TypeError: append() takes exactly one argument (3 given)

# %%
for index, row in data.iterrows():
    datosComparativos.append([row['Estatura'],row['Peso'],row['Altura']])

# %%
datosComparativos
# Out:
# [[35, 75, '1,7'],
#  [57, 88, '1,59'],
#  [40, 81, '1,66'],
#  [46, 73, '1,66'],
#  [67, 97, '1,68'],
#  [68, 99, '1,58'],
#  [65, 85, '1,56'],
#  [60, 70, '1,65'],
#  [56, 94, '1,72'],
#  [66, 68, '1,51'],
#  [54, 87, '1,73'],
#  [52, 87, '1,82'],
#  [65, 82, '1,58'],
#  [55, 79, '1,55'],
#  [67, 91, '1,61'],
#  [45, 96, '1,78'],
#  [44, 92, '1,8'],
#  [38, 65, '1,6'],
#  [34, 75, '1,7'],
#  [39, 84, '1,67'],
#  [44, 81, '1,66'],
#  [44, 73, '1,66'],
#  [43, 97, '1,68'],
#  [48, 95, '1,58'],
#  [50, 89, '1,56'],
#  [44, 71, '1,65'],
#  [57, 94, '1,72'],
#  [59, 68, '1,51'],
#  [44, 91, '1,73'],
#  [36, 83, '1,82'],
#  [39, 86, '1,58'],
#  [56, 75, '1,55'],
#  [55, 87, '1,61'],
#  [28, 96, '1,78'],
#  [38, 96, '1,8'],
#  [55, 69, '1,6'],
#  [45, 79, '1,7'],
#  [35, 84, '1,78'],
#  [46, 81, '1,66'],
#  [57, 73, '1,66'],
#  [55, 82, '1,68'],
#  [47, 90, '1,81'],
#  [44, 85, '1,74'],
#  [49, 70, '1,65'],
#  [66, 98, '1,72'],
#  [43, 84, '1,79'],
#  [67, 91, '1,73'],
# ...

# %%
type(datosComparativos)
# Out:
# list

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(datosComparativos,sexos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-c21448a8ef46> in <module>()
#       1 clf = tree.DecisionTreeClassifier()
# ----> 2 clf = clf.fit(datosComparativos,sexos)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# ...

# %%
nuevosDatosComparativos = []
for index, row in data.iterrows():
    nuevosDatosComparativos.append(row['Estatura'],row['Peso'],row['Altura'].replace(",", "."))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-f742099050e9> in <module>()
#       1 nuevosDatosComparativos = []
#       2 for index, row in data.iterrows():
# ----> 3     nuevosDatosComparativos.append(row['Estatura'],row['Peso'],row['Altura'].replace(",", "."))
#
# TypeError: append() takes exactly one argument (3 given)

# %%
nuevosDatosComparativos = []
for index, row in data.iterrows():
    nuevosDatosComparativos.append([row['Estatura'],row['Peso'],row['Altura'].replace(",", ".")])

# %%
nuevosDatosComparativos
# Out:
# [[35, 75, '1.7'],
#  [57, 88, '1.59'],
#  [40, 81, '1.66'],
#  [46, 73, '1.66'],
#  [67, 97, '1.68'],
#  [68, 99, '1.58'],
#  [65, 85, '1.56'],
#  [60, 70, '1.65'],
#  [56, 94, '1.72'],
#  [66, 68, '1.51'],
#  [54, 87, '1.73'],
#  [52, 87, '1.82'],
#  [65, 82, '1.58'],
#  [55, 79, '1.55'],
#  [67, 91, '1.61'],
#  [45, 96, '1.78'],
#  [44, 92, '1.8'],
#  [38, 65, '1.6'],
#  [34, 75, '1.7'],
#  [39, 84, '1.67'],
#  [44, 81, '1.66'],
#  [44, 73, '1.66'],
#  [43, 97, '1.68'],
#  [48, 95, '1.58'],
#  [50, 89, '1.56'],
#  [44, 71, '1.65'],
#  [57, 94, '1.72'],
#  [59, 68, '1.51'],
#  [44, 91, '1.73'],
#  [36, 83, '1.82'],
#  [39, 86, '1.58'],
#  [56, 75, '1.55'],
#  [55, 87, '1.61'],
#  [28, 96, '1.78'],
#  [38, 96, '1.8'],
#  [55, 69, '1.6'],
#  [45, 79, '1.7'],
#  [35, 84, '1.78'],
#  [46, 81, '1.66'],
#  [57, 73, '1.66'],
#  [55, 82, '1.68'],
#  [47, 90, '1.81'],
#  [44, 85, '1.74'],
#  [49, 70, '1.65'],
#  [66, 98, '1.72'],
#  [43, 84, '1.79'],
#  [67, 91, '1.73'],
# ...

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(nuevosDatosComparativos,sexos)

# %%
prediccion = clf.predict([[19,60,1.79]])

# %%
prediccion
# Out:
# array(['h'], dtype='<U1')

# %%
prediccion = clf.predict([[15,60,1.53]])

# %%
prediccion
# Out:
# array(['h'], dtype='<U1')

# %%
prediccion = clf.predict([[15,40,1.53]])

# %%
prediccion
# Out:
# array(['h'], dtype='<U1')

# %%
print prediccion
# Out:
#   File "<ipython-input-52-7fa92c154c8f>", line 1
#     print prediccion
#                    ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(prediccion)?

# %%
print(prediccion)
# Out:
# ['h']

# %%
prediccion = clf.predict([[57,88,1.59]])

# %%
print(prediccion)
# Out:
# ['m']

# %%
prediccion = clf.predict([[56,88,1.59]])

# %%
print(prediccion)
# Out:
# ['m']

# %%
prediccion = clf.predict([[55,88,1.59]])

# %%
print(prediccion)
# Out:
# ['m']

# %%
prediccion = clf.predict([[17,55,1.60]])

# %%
print(prediccion)
# Out:
# ['m']

# %%
prediccion = clf.predict([[19,65,1.78]])

# %%
print(prediccion)
# Out:
# ['h']

# %%
data
# Out:
#    Sexo  Estatura  Peso Altura
# 0     h        35    75    1,7
# 1     m        57    88   1,59
# 2     h        40    81   1,66
# 3     h        46    73   1,66
# 4     m        67    97   1,68
# 5     m        68    99   1,58
# 6     m        65    85   1,56
# 7     h        60    70   1,65
# 8     h        56    94   1,72
# 9     m        66    68   1,51
# 10    h        54    87   1,73
# 11    h        52    87   1,82
# 12    m        65    82   1,58
# 13    m        55    79   1,55
# 14    m        67    91   1,61
# 15    h        45    96   1,78
# 16    h        44    92    1,8
# 17    m        38    65    1,6
# 18    h        34    75    1,7
# 19    h        39    84   1,67
# 20    m        44    81   1,66
# 21    m        44    73   1,66
# 22    m        43    97   1,68
# 23    h        48    95   1,58
# 24    h        50    89   1,56
# 25    m        44    71   1,65
# 26    h        57    94   1,72
# 27    m        59    68   1,51
# 28    h        44    91   1,73
# ...
